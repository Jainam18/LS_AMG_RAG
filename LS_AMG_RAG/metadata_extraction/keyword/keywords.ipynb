# %% [markdown]
# ## Loading Data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import markdown

data = dict()
# Load all the files present in the data folder
for root, dirs, files in os.walk('../../data'):
    for file in files:
        # with open(os.path.join(root, file), 'rb') as f:
        #     # print(f.read())
        #     text = markdown.markdown(f.read())
        #     data[file] = text
            # break
        with open(os.path.join(root, file), "r", encoding="utf-8") as file:
            data[file] = file.read()

# %%
import os

for root, dirs, files in os.walk('../../data'):
    for file in files:
        print(root,dirs,file)
# Out:
# ../../data\business_docs [] Business Proposal.md
# ../../data\business_docs [] Marketing Plan.md
# ../../data\business_docs [] Progress Report.md
# ../../data\company_bylaws [] About Instagram.md
# ../../data\company_bylaws [] Board of Directors.md
# ../../data\company_bylaws [] Diversity, Equity, and Inclusion.md
# ../../data\company_bylaws [] Shareholders.md
# ../../data\financial_docs [] Balance Sheet.md
# ../../data\financial_docs [] Income Statement.md
# ../../data\financial_docs [] Tax Return.md
# ../../data\hr_docs_filled ['employee_contracts', 'employee_esops', 'employee_payslips'] Employee Handbook.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Ava Thomas.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_David Lee.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Emily Brown.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Ethan Rodriguez.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Eva Kim.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Jane Smith.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_John Doe.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Leo Kim.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Liam Kim.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Lucas Martinez.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Luna Nguyen.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Max Nguyen.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Mia Hernandez.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Michael Johnson.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Mila Lee.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Olivia Taylor.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Robert Martinez.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Sarah Wilson.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Sophia Garcia.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_William Anderson.md
# ../../data\hr_docs_filled\employee_contracts [] employee_contract_Zoe Lee.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Ava Thomas.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_David Lee.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Emily Brown.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Ethan Rodriguez.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Eva Kim.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Jane Smith.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_John Doe.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Leo Kim.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Liam Kim.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Lucas Martinez.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Luna Nguyen.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Max Nguyen.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Mia Hernandez.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Michael Johnson.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Mila Lee.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Olivia Taylor.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Robert Martinez.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Sarah Wilson.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Sophia Garcia.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_William Anderson.md
# ../../data\hr_docs_filled\employee_esops [] employee_esop_Zoe Lee.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Ava Thomas.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_David Lee.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Emily Brown.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Ethan Rodriguez.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Eva Kim.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Jane Smith.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_John Doe.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Leo Kim.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Liam Kim.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Lucas Martinez.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Luna Nguyen.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Max Nguyen.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Mia Hernandez.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Michael Johnson.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Mila Lee.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Olivia Taylor.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Robert Martinez.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Sarah Wilson.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Sophia Garcia.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_William Anderson.md
# ../../data\hr_docs_filled\employee_payslips [] employee_payslip_Zoe Lee.md
# ../../data\hr_docs_templates [] employee_payslip_template.md
# ../../data\hr_docs_templates [] employee_stock_ownership_plan_template.md
# ../../data\hr_docs_templates [] employment_contract_template.md

# %%
len(data)
# Out:
# 77

# %% [markdown]
# ## PKE Models

# %%
import pke
from pke.lang import stopwords
import string

# %%
def keyword(text, method='Yake'):
    if method=='Yake':
        extractor = pke.unsupervised.YAKE()
        stoplist = stopwords.get('english')
        extractor.load_document(input=text,
                                language='en',
                                stoplist=stoplist,
                                normalization=None)
        extractor.candidate_selection(n=3)
        window = 2
        use_stems = False
        extractor.candidate_weighting(window=window,
                                    use_stems=use_stems)
        threshold = 0.8
        keyphrases = extractor.get_n_best(n=10, threshold=threshold)
    elif method=='TextRank':
        pos = {'NOUN', 'PROPN', 'ADJ'}
        extractor = pke.unsupervised.TextRank()
        extractor.load_document(input=text,
                                language='en',
                                normalization=None)
        extractor.candidate_weighting(window=2,
                                    pos=pos,
                                    top_percent=0.33)
        keyphrases = extractor.get_n_best(n=10)
    elif method=='SingleRank':
        pos = {'NOUN', 'PROPN', 'ADJ'}
        extractor = pke.unsupervised.SingleRank()
        extractor.load_document(input=text,
                                language='en',
                                normalization=None)
        extractor.candidate_selection(pos=pos)
        extractor.candidate_weighting(window=10,
                                    pos=pos)
        keyphrases = extractor.get_n_best(n=10)
    elif method=='TopicRank':
        extractor = pke.unsupervised.TopicRank()
        stoplist = list(string.punctuation)
        stoplist += pke.lang.stopwords.get('en')
        extractor.load_document(input=text,
                                stoplist=stoplist)
        pos = {'NOUN', 'PROPN', 'ADJ'}
        extractor.candidate_selection(pos=pos)
        extractor.candidate_weighting(threshold=0.74, method='average')
        keyphrases = extractor.get_n_best(n=10)
    elif method=='PositionRank':
        pos = {'NOUN', 'PROPN', 'ADJ'}
        grammar = "NP: {<ADJ>*<NOUN|PROPN>+}"
        extractor = pke.unsupervised.PositionRank()
        extractor.load_document(input=text,
                                language='en',
                                normalization=None)
        extractor.candidate_selection(grammar=grammar,
                                    maximum_word_number=3)
        extractor.candidate_weighting(window=10,
                                    pos=pos)
        keyphrases = extractor.get_n_best(n=10)
    elif method=='MultipartiteRank':
        extractor = pke.unsupervised.MultipartiteRank()
        stoplist = list(string.punctuation)
        stoplist += pke.lang.stopwords.get('en')
        extractor.load_document(input=text,
                                stoplist=stoplist)
        pos = {'NOUN', 'PROPN', 'ADJ'}
        extractor.candidate_selection(pos=pos)
        extractor.candidate_weighting(alpha=1.1,
                                    threshold=0.74,
                                    method='average')
        keyphrases = extractor.get_n_best(n=10)
    else:
        pass
    return keyphrases

# %%
import pandas as pd
df = pd.DataFrame(data.items(), columns=['File', 'Text'])
df
# Out:
#                                          File  \
# 0                        Business Proposal.md
# 1                           Marketing Plan.md
# 2                          Progress Report.md
# 3                          About Instagram.md
# 4                       Board of Directors.md
# ..                                        ...
# 72       employee_payslip_William Anderson.md
# 73                employee_payslip_Zoe Lee.md
# 74               employee_payslip_template.md
# 75  employee_stock_ownership_plan_template.md
# 76            employment_contract_template.md
#
#                                                  Text
# 0   <p>b"\r\n### Company Name: Instagram\r\n### Ca...
# 1   <p>b'\r\n### Company Name: Instagram\r\n### Ca...
# 2   <p>b'# Instagram Progress Report\r\n\r\n| Proj...
# 3   <p>b"# About Instagram\r\n\r\n<strong>Overview...
# 4   <p>b"# Board of Directors\r\n\r\nThe Board of ...
# ..                                                ...
# 72  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 73  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 74  <p>b'# Employee Payslip\r\n\r\n## Employee Inf...
# 75  <p>b'# Employee Stock Ownership Plan (ESOP)\r\...
# 76  <p>b'# Employment Contract\r\n\r\n## Employee ...
#
# [77 rows x 2 columns]

# %%
keyword_methods = ['Yake', 'TextRank', 'SingleRank', 'TopicRank', 'PositionRank', 'MultipartiteRank']
keywords = []
for method in keyword_methods:
    df[method] = df['Text'].apply(lambda x: keyword(x, method=method))
    keywords.append(df[method].values)
# Out:
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top
# WARNING:root:Candidates are generated using 0.33-top

# %%
df
# Out:
#                                          File  \
# 0                        Business Proposal.md
# 1                           Marketing Plan.md
# 2                          Progress Report.md
# 3                          About Instagram.md
# 4                       Board of Directors.md
# ..                                        ...
# 72       employee_payslip_William Anderson.md
# 73                employee_payslip_Zoe Lee.md
# 74               employee_payslip_template.md
# 75  employee_stock_ownership_plan_template.md
# 76            employment_contract_template.md
#
#                                                  Text  \
# 0   <p>b"\r\n### Company Name: Instagram\r\n### Ca...
# 1   <p>b'\r\n### Company Name: Instagram\r\n### Ca...
# 2   <p>b'# Instagram Progress Report\r\n\r\n| Proj...
# 3   <p>b"# About Instagram\r\n\r\n<strong>Overview...
# 4   <p>b"# Board of Directors\r\n\r\nThe Board of ...
# ..                                                ...
# 72  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 73  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 74  <p>b'# Employee Payslip\r\n\r\n## Employee Inf...
# 75  <p>b'# Employee Stock Ownership Plan (ESOP)\r\...
# 76  <p>b'# Employment Contract\r\n\r\n## Employee ...
#
#                                                  Yake  \
# 0   [(social media marketing, 0.002417962165297132...
# 1   [(social media marketing, 1.007278240849013e-0...
# 2   [(direct messaging update, 8.708934970056568e-...
# 3   [(instagram, 0.02607871663367337), (strong, 0....
# 4   [(instagram, 0.01280533000974738), (board, 0.0...
# ..                                                ...
# 72  [(employee payslip, 0.0022734633413415174), (c...
# 73  [(employee payslip, 0.002274198026492155), (cu...
# 74  [(employee payslip, 0.0022529423857244176), (s...
# 75  [(employee stock ownership, 0.0001152205051629...
# 76  [(intellectual property, 0.0034684607361052766...
#
#                                              TextRank  \
# 0   [(visual content, 0.05635809323251077), (# # #...
# 1   [(marketing objectives:</strong>\r\n- increase...
# 2   [(| user feedback, 0.19982836181623714), (| us...
# 3   [(visual content, 0.03562114105346172), (socia...
# 4   [(brand awareness.\r\n\r\n # # contributions, ...
# ..                                                ...
# 72  [(# # employee, 0.19218371052598202), (# # net...
# 73  [(# # employee, 0.19452824309451516), (# # net...
# 74  [(# # employee, 0.1728828564205594), (# # net,...
# 75  [(# # employee information:\r\n- <, 0.23273271...
# 76  [(# # employee information:\r\n- <, 0.24643160...
#
#                                            SingleRank  \
# 0   [(comprehensive social media marketing service...
# 1   [(current social media marketing trends, 0.088...
# 2   [(video duration limit | content moderation po...
# 3   [(advocacy campaigns\r\n\r\n < strong, 0.05634...
# 4   [(# board composition\r\n\r\nthe board, 0.0950...
# ..                                                ...
# 72  [(customer support\r\n\r\n # # pay period:\r\n...
# 73  [(customer success\r\n\r\n # # pay period:\r\n...
# 74  [(# employee information:\r\n- < strong, 0.266...
# 75  [(# employee information:\r\n- < strong, 0.204...
# 76  [(# employee information:\r\n- < strong, 0.257...
#
#                                             TopicRank  \
# 0   [(strong, 0.10865335318122646), (visual conten...
# 1   [(strong, 0.1533084555366908), (relevant influ...
# 2   [(developers, 0.22126828410600863), (designers...
# 3   [(users, 0.05817594536900966), (instagram, 0.0...
# 4   [(instagram, 0.0979706959405189), (board membe...
# ..                                                ...
# 72  [(strong, 0.21439941069804597), (september, 0....
# 73  [(strong, 0.2323191868586359), (pay period, 0....
# 74  [(strong, 0.18167362159262998), (earnings, 0.1...
# 75  [(employee, 0.11620143584420564), (strong, 0.0...
# 76  [(employer, 0.1558321730207338), (employee, 0....
#
#                                          PositionRank  \
# 0   [(# company name, 0.07905466811226274), (socia...
# 1   [(# company name, 0.08739246617167683), (# doc...
# 2   [(progress |, 0.2822538647359515), (| integrat...
# 3   [(instagram community today, 0.055395335208253...
# 4   [(# board, 0.1028890006977222), (directors\r\n...
# ..                                                ...
# 72  [(b'\r\n # employee, 0.2145245199455731), (wil...
# 73  [(b'\r\n # employee, 0.22242752466112778), (# ...
# 74  [(# employee payslip\r\n\r\n, 0.19604071167975...
# 75  [(# esop details:\r\n-, 0.11220397399007889), ...
# 76  [(# employment contract\r\n\r\n, 0.14483441417...
#
#                                      MultipartiteRank
# 0   [(strong, 0.08479113790373548), (brand presenc...
# 1   [(strong, 0.1237602253731655), (relevant influ...
# 2   [(developers, 0.22126828410600868), (designers...
# 3   [(users, 0.05473342842746924), (instagram, 0.0...
# 4   [(instagram, 0.08740494042510544), (board memb...
# ..                                                ...
# 72  [(strong, 0.21620878655182965), (september, 0....
# 73  [(strong, 0.24799160485023408), (pay period, 0...
# 74  [(strong, 0.18641698980184895), (earnings, 0.1...
# 75  [(employee, 0.11684321550977161), (strong, 0.0...
# 76  [(employer, 0.1420613170093485), (employee, 0....
#
# [77 rows x 8 columns]

# %%
# df['Yake'][0]
for i in range(len(df)):
    df['Yake'][i] = [x[0] for x in df['Yake'][i]]
    df['TextRank'][i] = [x[0] for x in df['TextRank'][i]]
    df['SingleRank'][i] = [x[0] for x in df['SingleRank'][i]]
    df['TopicRank'][i] = [x[0] for x in df['TopicRank'][i]]
    df['PositionRank'][i] = [x[0] for x in df['PositionRank'][i]]
    df['MultipartiteRank'][i] = [x[0] for x in df['MultipartiteRank'][i]]

# %%
df
# Out:
#                                     File  \
# 0                   Business Proposal.md
# 1                      Marketing Plan.md
# 2                     Progress Report.md
# 3                     About Instagram.md
# 4                  Board of Directors.md
# ..                                   ...
# 69   employee_payslip_Robert Martinez.md
# 70      employee_payslip_Sarah Wilson.md
# 71     employee_payslip_Sophia Garcia.md
# 72  employee_payslip_William Anderson.md
# 73           employee_payslip_Zoe Lee.md
#
#                                                  Text  \
# 0   <p>b"\r\n### Company Name: Instagram\r\n### Ca...
# 1   <p>b'\r\n### Company Name: Instagram\r\n### Ca...
# 2   <p>b'# Instagram Progress Report\r\n\r\n| Proj...
# 3   <p>b"# About Instagram\r\n\r\n<strong>Overview...
# 4   <p>b"# Board of Directors\r\n\r\nThe Board of ...
# ..                                                ...
# 69  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 70  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 71  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 72  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
# 73  <p>b'\r\n# Employee Payslip\r\n\r\n## Employee...
#
#                                                  Yake  \
# 0   [social media marketing, media marketing servi...
# 1   [social media marketing, media marketing trend...
# 2   [direct messaging update, explore algorithm en...
# 3   [instagram, strong, users, platform, community...
# 4   [instagram, board, chief marketing officer, hi...
# ..                                                ...
# 69  [employee payslip, robert martinez, strong, em...
# 70  [employee payslip, sarah wilson, strong, emplo...
# 71  [employee payslip, sophia garcia, strong, empl...
# 72  [employee payslip, customer support, william a...
# 73  [employee payslip, customer success, zoe lee, ...
#
#                                              TextRank  \
# 0   [visual content, # # # company, influencer col...
# 1   [marketing objectives:</strong>\r\n- increase ...
# 2   [| user feedback, | user adoption, | content m...
# 3   [visual content, social media platform, user e...
# 4   [brand awareness.\r\n\r\n # # contributions, c...
# ..                                                ...
# 69  [# # employee, # # net, # # pay, # employee, #...
# 70  [human resources\r\n\r\n # # pay, # # employee...
# 71  [# # employee, # # net, # # pay, # employee, #...
# 72  [# # employee, # # net, # # pay, # #, # employ...
# 73  [# # employee, # # net, # # pay, # #, # employ...
#
#                                            SingleRank  \
# 0   [comprehensive social media marketing services...
# 1   [current social media marketing trends, social...
# 2   [video duration limit | content moderation pol...
# 3   [advocacy campaigns\r\n\r\n < strong, instagra...
# 4   [# board composition\r\n\r\nthe board, popular...
# ..                                                ...
# 69  [# employee information:\r\n- < strong, # pay ...
# 70  [# employee information:\r\n- < strong, # pay ...
# 71  [# employee information:\r\n- < strong, # pay ...
# 72  [customer support\r\n\r\n # # pay period:\r\n-...
# 73  [customer success\r\n\r\n # # pay period:\r\n-...
#
#                                             TopicRank  \
# 0   [strong, visual content, brand presence, influ...
# 1   [strong, relevant influencers, brand advocacy,...
# 2   [developers, designers, hold, encryption, secu...
# 3   [users, instagram, platform, features, strong,...
# 4   [instagram, board members, directors, strong, ...
# ..                                                ...
# 69  [strong, july, pay period, earnings, deduction...
# 70  [strong, june, pay period, earnings, employee,...
# 71  [strong, november, pay period, earnings, deduc...
# 72  [strong, september, pay period, earnings, dedu...
# 73  [strong, pay period, earnings, employee, deduc...
#
#                                          PositionRank  \
# 0   [# company name, social media strategy, social...
# 1   [# company name, # document title, content mar...
# 2   [progress |, | integration issues, moderation ...
# 3   [instagram community today, social media platf...
# 4   [# board, directors\r\n\r\nthe board, board me...
# ..                                                ...
# 69  [b'\r\n # employee, employee name:</strong, ro...
# 70  [b'\r\n # employee, employee id:</strong, empl...
# 71  [b'\r\n # employee, sophia garcia\r\n- <, 5,45...
# 72  [b'\r\n # employee, william anderson\r\n- <, #...
# 73  [b'\r\n # employee, # earnings:\r\n-, employee...
#
#                                      MultipartiteRank
# 0   [strong, brand presence, engagement, visual co...
# 1   [strong, relevant influencers, marketing plan,...
# 2   [developers, designers, hold, encryption, secu...
# 3   [users, instagram, platform, features, strong,...
# 4   [instagram, board members, directors, company,...
# ..                                                ...
# 69  [strong, july, pay period, earnings, robert ma...
# 70  [strong, june, pay period, employee, earnings,...
# 71  [strong, november, pay period, earnings, deduc...
# 72  [strong, september, pay period, employee, earn...
# 73  [strong, pay period, employee, earnings, zoe l...
#
# [74 rows x 8 columns]

# %%
df.drop('Text', axis=1, inplace=True)

# %%
df.to_csv('keywords.csv', index=False)

# %% [markdown]
# ## Evaluation

# %%
import pandas as pd
df_true = pd.read_csv('keywords_truelabels.csv')
df_pred = pd.read_csv('keywords.csv')

# %%
df_true
# Out:
#                                   File  \
# 0                Board of Directors.md
# 1  Diversity, Equity, and Inclusion.md
# 2                     Balance Sheet.md
# 3             employee_esop_Eva Kim.md
# 4  employee_payslip_Ethan Rodriguez.md
# 5                    Marketing Plan.md
# 6                 Business Proposal.md
# 7                        Tax Return.md
# 8       employee_contract_David Lee.md
# 9                 Employee Handbook.md
#
#                               Gold Standard Keywords
# 0  ['instagram',  'board members',  'strategic gu...
# 1  ['diverse', 'equity', 'inclusive workplace', '...
# 2  ['current assests', 'non-current assests', 'in...
# 3  ['employee stock ownership', 'content moderati...
# 4  ['employee payslip', 'security officer', 'allo...
# 5  ['social media marketing', 'advertising campai...
# 6  ['social media marketing', 'brand presence', '...
# 7  ['tax rate', 'total income', 'employment incom...
# 8  ['employment contract', 'administration', 'res...
# 9  ['employees', 'mission', 'discrimination', 'ha...

# %%
print(df_true.dtypes)
# Out:
# File                      object
# Gold Standard Keywords    object
# dtype: object

# %%
import ast

# df['Your_Column'] = df['Your_Column'].apply(ast.literal_eval)
df_true['Gold Standard Keywords'] = df_true['Gold Standard Keywords'].apply(ast.literal_eval)
df_pred['Yake'] = df_pred['Yake'].apply(ast.literal_eval)
df_pred['TextRank'] = df_pred['TextRank'].apply(ast.literal_eval)
df_pred['SingleRank'] = df_pred['SingleRank'].apply(ast.literal_eval)
df_pred['TopicRank'] = df_pred['TopicRank'].apply(ast.literal_eval)
df_pred['PositionRank'] = df_pred['PositionRank'].apply(ast.literal_eval)
df_pred['MultipartiteRank'] = df_pred['MultipartiteRank'].apply(ast.literal_eval)

# %%
type(df_true['Gold Standard Keywords'][0])
# Out:
# list

# %%
type(df_pred['Yake'][0])
# Out:
# list

# %%
df_merged = df_true.merge(df_pred, how='left', on='File')

# %%
df_merged
# Out:
#                                   File  \
# 0                Board of Directors.md
# 1  Diversity, Equity, and Inclusion.md
# 2                     Balance Sheet.md
# 3             employee_esop_Eva Kim.md
# 4  employee_payslip_Ethan Rodriguez.md
# 5                    Marketing Plan.md
# 6                 Business Proposal.md
# 7                        Tax Return.md
# 8       employee_contract_David Lee.md
# 9                 Employee Handbook.md
#
#                               Gold Standard Keywords  \
# 0  [instagram, board members, strategic guidance,...
# 1  [diverse, equity, inclusive workplace, dei, br...
# 2  [current assests, non-current assests, intangi...
# 3  [employee stock ownership, content moderation,...
# 4  [employee payslip, security officer, allowance...
# 5  [social media marketing, advertising campaigns...
# 6  [social media marketing, brand presence, visua...
# 7  [tax rate, total income, employment income, in...
# 8  [employment contract, administration, responsi...
# 9  [employees, mission, discrimination, harassmen...
#
#                                                 Yake  \
# 0  [instagram, board, chief marketing officer, hi...
# 1  [diverse, strong, equity, dei, instagram, dive...
# 2  [non-current assets, current assets, total ass...
# 3  [employee stock ownership, stock ownership pla...
# 4  [employee payslip, ethan rodriguez, strong, em...
# 5  [social media marketing, media marketing trend...
# 6  [social media marketing, media marketing servi...
# 7  [employment income, investment income, taxable...
# 8  [david lee, intellectual property, hereinafter...
# 9  [employee, table, company, employee handbook, ...
#
#                                             TextRank  \
# 0  [brand awareness.\r\n\r\n # # contributions, c...
# 1  [diverse content, diverse candidate, diverse u...
# 2  [|\r\n| non-current assets |, |\r\n| non-curre...
# 3  [# # employee information:\r\n- <, # employee ...
# 4  [# # employee, # # net, # # pay, # #, # employ...
# 5  [marketing objectives:</strong>\r\n- increase ...
# 6  [visual content, # # # company, influencer col...
# 7  [|\r\n| tax, |\r\n| total, |\r\n|, total incom...
# 8  [# # employee information:\r\n- <, # #, # empl...
# 9  [contact information\r\n\r\n # #, # # company,...
#
#                                           SingleRank  \
# 0  [# board composition\r\n\r\nthe board, popular...
# 1  [< strong, diverse content creators, diverse c...
# 2  [|\r\n| non-current assets |, |\r\n| non-curre...
# 3  [# employee information:\r\n- < strong, b'\r\n...
# 4  [# employee information:\r\n- < strong, # pay ...
# 5  [current social media marketing trends, social...
# 6  [comprehensive social media marketing services...
# 7  [|\r\n| employment income, |\r\n| taxable inco...
# 8  [# employee information:\r\n- < strong, compan...
# 9  [# employee handbook\r\n\r\n, # company name, ...
#
#                                            TopicRank  \
# 0  [instagram, board members, directors, strong, ...
# 1  [inclusive workplace, diverse, committed, equi...
# 2  [december, strong, category, intangible assets...
# 3  [employee, rights, strong, hereinafter, alloca...
# 4  [strong, december, pay period, earnings, emplo...
# 5  [strong, relevant influencers, brand advocacy,...
# 6  [strong, visual content, brand presence, influ...
# 7       [category, december,  ,  ,  ,  ,  ,  ,  ,  ]
# 8  [strong, employee, employer, hereinafter, empl...
# 9  [employees, time, company policies, benefits, ...
#
#                                         PositionRank  \
# 0  [# board, directors\r\n\r\nthe board, board me...
# 1  [# diversity, diverse content creators, divers...
# 2  [|\r\n| current assets, |\r\n| total assets, |...
# 3  [# esop details:\r\n-, employee name:</strong,...
# 4  [b'\r\n # employee, employee id:</strong, empl...
# 5  [# company name, # document title, content mar...
# 6  [# company name, social media strategy, social...
# 7  [|\r\n| tax owed, |\r\n| tax rate, |\r\n| empl...
# 8  [# terms, employee, employment contract, compa...
# 9  [# employee handbook\r\n\r\n, # company name, ...
#
#                                     MultipartiteRank
# 0  [instagram, board members, directors, company,...
# 1  [inclusive workplace, diverse, equity, committ...
# 2  [december, strong, category, intangible assets...
# 3  [employee, strong, rights, hereinafter, alloca...
# 4  [strong, december, pay period, employee, earni...
# 5  [strong, relevant influencers, marketing plan,...
# 6  [strong, brand presence, engagement, visual co...
# 7       [december, category,  ,  ,  ,  ,  ,  ,  ,  ]
# 8  [strong, employee, employer, hereinafter, empl...
# 9  [employees, time, company policies, mission, c...

# %%
keyword_methods = ['Yake', 'TextRank', 'SingleRank', 'TopicRank', 'PositionRank', 'MultipartiteRank']

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

def evaluate_keywords(gold_standard, model_predictions):
    gold_binary = [1 if keyword in gold_standard else 0 for keyword in model_predictions]
    model_binary = [1 if keyword in model_predictions else 0 for keyword in gold_standard]
    cm = confusion_matrix(gold_binary, model_binary)
    # Calculate precision, recall, and F1-score
    precision = precision_score(gold_binary, model_binary)
    recall = recall_score(gold_binary, model_binary)
    f1 = f1_score(gold_binary, model_binary)

    return precision, recall, f1,cm

# %%
results = {}

for method in keyword_methods:
    init_results = []
    for i in range(len(df_merged)):
        precision, recall, f1, cm = evaluate_keywords(df_merged['Gold Standard Keywords'][i], df_merged[method][i])
        init_results.append({'Precision': precision, 'Recall': recall, 'F1-score': f1})
    results[method] = init_results
# Out:
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\MajorProject\majorproject\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
results
# Out:
# {'Yake': [{'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.6666666666666666,
#    'Recall': 0.6666666666666666,
#    'F1-score': 0.6666666666666666},
#   {'Precision': 0.6, 'Recall': 0.6, 'F1-score': 0.6},
#   {'Precision': 0.75, 'Recall': 0.75, 'F1-score': 0.75},
#   {'Precision': 0.75, 'Recall': 0.75, 'F1-score': 0.75},
#   {'Precision': 0.6666666666666666,
#    'Recall': 0.6666666666666666,
#    'F1-score': 0.6666666666666666},
#   {'Precision': 0.5, 'Recall': 0.5, 'F1-score': 0.5},
#   {'Precision': 0.8888888888888888,
#    'Recall': 0.8888888888888888,
#    'F1-score': 0.8888888888888888},
#   {'Precision': 0.5, 'Recall': 0.5, 'F1-score': 0.5},
#   {'Precision': 0.6666666666666666,
#    'Recall': 0.8,
#    'F1-score': 0.7272727272727273}],
#  'TextRank': [{'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0}],
#  'SingleRank': [{'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.5, 'Recall': 0.5, 'F1-score': 0.5},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0}],
#  'TopicRank': [{'Precision': 0.8333333333333334,
#    'Recall': 0.8333333333333334,
#    'F1-score': 0.8333333333333334},
#   {'Precision': 0.875, 'Recall': 0.875, 'F1-score': 0.875},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.5, 'Recall': 0.5, 'F1-score': 0.5},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.4, 'Recall': 0.5, 'F1-score': 0.4444444444444444},
#   {'Precision': 0.5, 'Recall': 0.5, 'F1-score': 0.5},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.5714285714285714,
#    'Recall': 0.6666666666666666,
#    'F1-score': 0.6153846153846154}],
#  'PositionRank': [{'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0}],
#  'MultipartiteRank': [{'Precision': 0.5714285714285714,
#    'Recall': 0.5714285714285714,
#    'F1-score': 0.5714285714285714},
#   {'Precision': 0.5714285714285714,
#    'Recall': 0.5714285714285714,
#    'F1-score': 0.5714285714285714},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.25,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.2857142857142857},
#   {'Precision': 0.6, 'Recall': 0.6, 'F1-score': 0.6},
#   {'Precision': 0.0, 'Recall': 0.0, 'F1-score': 0.0},
#   {'Precision': 0.3333333333333333,
#    'Recall': 0.3333333333333333,
#    'F1-score': 0.3333333333333333},
#   {'Precision': 0.7142857142857143,
#    'Recall': 0.8333333333333334,
#    'F1-score': 0.7692307692307693}]}

# %%
average_results = {}

for method in keyword_methods:
    precision_list = [result['Precision'] for result in results[method]]
    recall_list = [result['Recall'] for result in results[method]]
    f1_list = [result['F1-score'] for result in results[method]]

    average_precision = sum(precision_list) / len(precision_list)
    average_recall = sum(recall_list) / len(recall_list)
    average_f1 = sum(f1_list) / len(f1_list)

    average_results[method] = {'Average Precision': average_precision, 'Average Recall': average_recall, 'Average F1-score': average_f1}

average_results
# Out:
# {'Yake': {'Average Precision': 0.6322222222222222,
#   'Average Recall': 0.6455555555555554,
#   'Average F1-score': 0.6382828282828282},
#  'TextRank': {'Average Precision': 0.0,
#   'Average Recall': 0.0,
#   'Average F1-score': 0.0},
#  'SingleRank': {'Average Precision': 0.05,
#   'Average Recall': 0.05,
#   'Average F1-score': 0.05},
#  'TopicRank': {'Average Precision': 0.46797619047619043,
#   'Average Recall': 0.4875000000000001,
#   'Average F1-score': 0.47681623931623934},
#  'PositionRank': {'Average Precision': 0.06666666666666667,
#   'Average Recall': 0.06666666666666667,
#   'Average F1-score': 0.06666666666666667},
#  'MultipartiteRank': {'Average Precision': 0.3373809523809524,
#   'Average Recall': 0.3576190476190476,
#   'Average F1-score': 0.3464468864468865}}

# %%
df = pd.DataFrame(average_results)

# %%
df
# Out:
#                        Yake  TextRank  SingleRank  TopicRank  PositionRank  \
# Average Precision  0.632222       0.0        0.05   0.467976      0.066667
# Average Recall     0.645556       0.0        0.05   0.487500      0.066667
# Average F1-score   0.638283       0.0        0.05   0.476816      0.066667
#
#                    MultipartiteRank
# Average Precision          0.337381
# Average Recall             0.357619
# Average F1-score           0.346447

# %%
df.to_csv('keyword_method_results.csv', index=False)

# %% [markdown]
# ## Overall Yake algorithm gives the best results over keywords, followed by TopicRank and Multipartite Rank
